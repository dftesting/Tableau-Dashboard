# %%
import pandas as pd

df=pd.read_csv('D:\DATA ANALYST\DASHBOARD\superstore.csv',low_memory=False)

unused_columns = df.columns[df.nunique() <= 1]
print(unused_columns)
# Out:
# Index(['记录数'], dtype='object')

# %%
df.drop(unused_columns, axis=1, inplace=True)

# %%
df
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market               Order.Date  \
# 0      Lycoris Saunders       0.0     US  2011-01-07 00:00:00.000
# 1         Mark Van Huff       0.0     US  2011-01-21 00:00:00.000
# 2          Chad Sievert       0.0     US  2011-08-05 00:00:00.000
# 3          Chad Sievert       0.0     US  2011-08-05 00:00:00.000
# 4        Arthur Prichep       0.0     US  2011-09-29 00:00:00.000
# ...                 ...       ...    ...                      ...
# 51285    Alice McCarthy       0.2     US  2014-12-03 00:00:00.000
# 51286    Alice McCarthy       0.2     US  2014-12-03 00:00:00.000
# 51287    Hallie Redmond       0.2     US  2014-12-18 00:00:00.000
# 51288     Robert Marley       0.2     US  2014-12-25 00:00:00.000
# 51289      Fred Hopkins       0.2     US  2014-12-26 00:00:00.000
#
#              Order.ID Order.Priority  ... Sales      Segment  \
# 0      CA-2011-130813           High  ...    19     Consumer
# 1      CA-2011-148614         Medium  ...    19     Consumer
# 2      CA-2011-118962         Medium  ...    21     Consumer
# 3      CA-2011-118962         Medium  ...   111     Consumer
# 4      CA-2011-146969           High  ...     6     Consumer
# ...               ...            ...  ...   ...          ...
# 51285  CA-2014-109701           High  ...    69    Corporate
# 51286  CA-2014-109701           High  ...     9    Corporate
# 51287  CA-2014-106964         Medium  ...    12  Home Office
# 51288  CA-2014-145219       Critical  ...    90  Home Office
# 51289  CA-2014-121398         Medium  ...   154    Corporate
#
#                      Ship.Date       Ship.Mode Shipping.Cost       State  \
# 0      2011-01-09 00:00:00.000    Second Class          4.37  California
# 1      2011-01-26 00:00:00.000  Standard Class          0.94  California
# 2      2011-08-09 00:00:00.000  Standard Class          1.81  California
# 3      2011-08-09 00:00:00.000  Standard Class          4.59  California
# 4      2011-10-03 00:00:00.000  Standard Class          1.32  California
# ...                        ...             ...           ...         ...
# 51285  2014-12-04 00:00:00.000        Same Day          5.15  California
# 51286  2014-12-04 00:00:00.000        Same Day          0.44  California
# 51287  2014-12-21 00:00:00.000     First Class          0.31  California
# 51288  2014-12-26 00:00:00.000     First Class         15.95  California
# 51289  2014-12-30 00:00:00.000  Standard Class          9.59  California
#
#        Sub.Category  Year        Market2 weeknum
# 0             Paper  2011  North America       2
# 1             Paper  2011  North America       4
# 2             Paper  2011  North America      32
# 3             Paper  2011  North America      32
# 4             Paper  2011  North America      40
# ...             ...   ...            ...     ...
# 51285       Binders  2014  North America      49
# 51286       Binders  2014  North America      49
# 51287       Binders  2014  North America      51
# 51288       Binders  2014  North America      52
# 51289       Binders  2014  North America      52
#
# [51290 rows x 26 columns]

# %%
# make columns name uniform, change . with _

# %%
df.rename(columns=lambda x: x.strip().replace(".", "_"), inplace=True)
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer_ID', 'Customer_Name',
#        'Discount', 'Market', 'Order_Date', 'Order_ID', 'Order_Priority',
#        'Product_ID', 'Product_Name', 'Profit', 'Quantity', 'Region', 'Row_ID',
#        'Sales', 'Segment', 'Ship_Date', 'Ship_Mode', 'Shipping_Cost', 'State',
#        'Sub_Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
column_data_types = df.dtypes
print(column_data_types)
# Out:
# Category           object
# City               object
# Country            object
# Customer_ID        object
# Customer_Name      object
# Discount          float64
# Market             object
# Order_Date         object
# Order_ID           object
# Order_Priority     object
# Product_ID         object
# Product_Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row_ID              int64
# Sales               int64
# Segment            object
# Ship_Date          object
# Ship_Mode          object
# Shipping_Cost     float64
# State              object
# Sub_Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])
column_data_types = df.dtypes
print(column_data_types)
# Out:
# Category                  object
# City                      object
# Country                   object
# Customer_ID               object
# Customer_Name             object
# Discount                 float64
# Market                    object
# Order_Date        datetime64[ns]
# Order_ID                  object
# Order_Priority            object
# Product_ID                object
# Product_Name              object
# Profit                   float64
# Quantity                   int64
# Region                    object
# Row_ID                     int64
# Sales                      int64
# Segment                   object
# Ship_Date         datetime64[ns]
# Ship_Mode                 object
# Shipping_Cost            float64
# State                     object
# Sub_Category              object
# Year                       int64
# Market2                   object
# weeknum                    int64
# dtype: object

# %%
# only select European market to this Dashboard Project

# %%
df2 = df[df['Market'].isin(['EU'])]
#df2['Order_Date'] = pd.to_datetime(df2['Order_Date'])
#df2['Month'] = df2['Order_Date'].dt.month
df3 = pd.DataFrame(df2)

# Add a new column 'Month' representing the month (1 to 12)
df3['Month'] = df3['Order_Date'].dt.month

df3
# Out:
#               Category            City Country Customer_ID      Customer_Name  \
# 3129   Office Supplies      Echirolles  France   MG-178902   Michael Granlund
# 3130   Office Supplies      Echirolles  France   MG-178902   Michael Granlund
# 3131   Office Supplies    Noisy-le-Sec  France   SN-205602       Skye Norling
# 3132   Office Supplies     Carcassonne  France   TW-210252  Tamara Willingham
# 3133   Office Supplies     Carcassonne  France   TW-210252  Tamara Willingham
# ...                ...             ...     ...         ...                ...
# 43415       Technology  Ivry-sur-Seine  France   TS-216102       Troy Staebel
# 43416  Office Supplies     Les Mureaux  France   JH-159852        Joseph Holt
# 43417       Technology       Sarcelles  France   PG-188952      Paul Gonzalez
# 43418       Technology       Sarcelles  France   PG-188952      Paul Gonzalez
# 43419  Office Supplies            Evry  France   PW-192402       Pierre Wener
#
#        Discount Market Order_Date         Order_ID Order_Priority  ...  \
# 3129       0.00     EU 2011-01-05  ES-2011-3848439         Medium  ...
# 3130       0.00     EU 2011-01-05  ES-2011-3848439         Medium  ...
# 3131       0.00     EU 2011-03-18  ES-2011-5522951         Medium  ...
# 3132       0.00     EU 2011-03-24  ES-2011-5504927       Critical  ...
# 3133       0.00     EU 2011-03-24  ES-2011-5504927       Critical  ...
# ...         ...    ...        ...              ...            ...  ...
# 43415      0.15     EU 2014-12-11  IT-2014-2250081         Medium  ...
# 43416      0.10     EU 2014-12-20  ES-2014-1728888         Medium  ...
# 43417      0.15     EU 2014-12-29  ES-2014-5861616         Medium  ...
# 43418      0.15     EU 2014-12-29  ES-2014-5861616         Medium  ...
# 43419      0.10     EU 2014-12-30  ES-2014-1271577         Medium  ...
#
#            Segment  Ship_Date       Ship_Mode  Shipping_Cost  \
# 3129   Home Office 2011-01-07     First Class          15.27
# 3130   Home Office 2011-01-07     First Class          20.64
# 3131   Home Office 2011-03-20     First Class           7.06
# 3132   Home Office 2011-03-27     First Class          95.81
# 3133   Home Office 2011-03-27     First Class          48.16
# ...            ...        ...             ...            ...
# 43415     Consumer 2014-12-16  Standard Class          24.23
# 43416     Consumer 2014-12-25  Standard Class           5.14
# 43417     Consumer 2015-01-03  Standard Class          45.60
# 43418     Consumer 2015-01-03  Standard Class           6.49
# 43419     Consumer 2015-01-03  Standard Class           4.17
#
#                       State  Sub_Category  Year Market2 weeknum Month
# 3129            Rhône-Alpes           Art  2011      EU       2     1
# 3130            Rhône-Alpes           Art  2011      EU       2     1
# 3131          Ile-de-France     Fasteners  2011      EU      12     3
# 3132   Languedoc-Roussillon       Binders  2011      EU      13     3
# 3133   Languedoc-Roussillon       Binders  2011      EU      13     3
# ...                     ...           ...   ...     ...     ...   ...
# 43415         Ile-de-France       Copiers  2014      EU      50    12
# 43416         Ile-de-France       Storage  2014      EU      51    12
# 43417         Ile-de-France      Machines  2014      EU      53    12
# 43418         Ile-de-France      Machines  2014      EU      53    12
# 43419         Ile-de-France       Storage  2014      EU      53    12
#
# [10000 rows x 27 columns]

# %%
# save dataframe df2 to cleaned csv file

# %%
df3.to_csv('D:\superstore_cleaned.csv', index=False)
